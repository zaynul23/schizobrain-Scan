# %%
import pandas as pd
ddat=pd.read_

# %%
strr='''
CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,CONTROL
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,SCHZ
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,BIPOLAR
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD
,ADHD

 '''

# %%
d=strr.split(',')

# %%
import numpy as np
dat=np.array(d)
print(dat[dat=="SCHZ\n"].shape)
# Out:
# (50,)

# %%
dat
# Out:
# array(['\nCONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
#        'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n', 'CONTROL\n',
# ...
